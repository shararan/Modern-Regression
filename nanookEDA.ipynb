# %%
import numpy as np 
import requests
import pandas as pd
from io import StringIO
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
import seaborn as sns
from statsmodels.nonparametric.smoothers_lowess import lowess

# %%
# df = pd.read_csv("train.csv")
# df = df.drop(columns=["id", "date"])
# print(df.head())

# %%
df = pd.read_csv("train.csv")
df = df.drop(columns=["id", "date"])

# for i in range(2, 14):
#     df = df.drop(columns=[f"temp_{i}", f"wind_{i}", f"temp_night_{i}", f"wind_night_{i}", f"temp_night_{i}", f"ssrd_ratio_{i}"])

for i in range(1, 14):
    df = df.drop(columns=[f"wind_{i}", f"wind_night_{i}", f"ssrd_ratio_{i}"])

# ind = 12
for i in range(1, 14):
    df = df.drop(columns=[f"temp_night_{i}"])

print(df.shape)
# Out:
# (3287, 14)

# %% [markdown]
# Col 5 and Col 1 are the exact same for temp and temp_night

# %%
df = pd.read_csv("train.csv")
df = df.drop(columns=["id", "date"])

# for i in range(2, 14):
#     df = df.drop(columns=[f"temp_{i}", f"wind_{i}", f"temp_night_{i}", f"wind_night_{i}", f"temp_night_{i}", f"ssrd_ratio_{i}"])

for i in range(1, 14):
    df = df.drop(columns=[f"temp_{i}", f"wind_{i}", f"temp_night_{i}", f"wind_night_{i}", f"temp_night_{i}"])

# ind = 12
# for i in range(1, 14):
#     df = df.drop(columns=[f"temp_night_{i}"])

print(df.shape)
# Out:
# (3287, 14)

# %% [markdown]
# Col 1 and Col 5 are the exact same

# %%
df = pd.read_csv("train.csv")
df = df.drop(columns=["id", "date"])

# for i in range(2, 14):
#     df = df.drop(columns=[f"temp_{i}", f"wind_{i}", f"temp_night_{i}", f"wind_night_{i}", f"temp_night_{i}", f"ssrd_ratio_{i}"])

for i in range(1, 14):
    df = df.drop(columns=[f"temp_{i}", f"temp_night_{i}", f"wind_night_{i}", f"temp_night_{i}", f"ssrd_ratio_{i}"])

# ind = 12
# for i in range(1, 14):
#     df = df.drop(columns=[f"temp_night_{i}"])

print(df.shape)
# Out:
# (3287, 14)

# %% [markdown]
# Col 5 is completely redundant

# %%
df = pd.read_csv("train.csv")
df = df.drop(columns=["id", "date"])

for i in range(5, 5):
    df = df.drop(columns=[f"temp_{i}", f"wind_{i}", f"temp_night_{i}", f"wind_night_{i}", f"temp_night_{i}", f"ssrd_ratio_{i}"])

# for i in range(1, 14):
#     df = df.drop(columns=[f"temp_{i}", f"temp_night_{i}", f"wind_night_{i}", f"temp_night_{i}", f"ssrd_ratio_{i}"])

# ind = 12
# for i in range(1, 14):
#     df = df.drop(columns=[f"temp_night_{i}"])

print(df.shape)
# print(df.head())

df_wo_y = df.drop(columns=['demand'])

X = df_wo_y.to_numpy()
G = X.T @ X
eigvals, eigvecs = np.linalg.eigh(X.T @ X)

# print(eigvals)
print(eigvecs[0])
# Out:
# (3287, 66)
# [-7.07106781e-01  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   7.14170667e-07  1.32965073e-02  6.39319457e-03  6.46992105e-03
#   2.41447723e-03  1.37749497e-02  1.28037868e-02 -5.36667350e-03
#  -1.02304588e-02 -5.06460266e-03 -2.09473772e-02 -1.65616061e-03
#  -4.24177249e-02 -1.92874584e-02 -4.10623100e-02 -2.26549590e-03
#   3.71744914e-02  7.15905712e-02  5.67381772e-02  1.33854314e-02
#  -6.26583952e-02 -5.28188426e-02 -1.85013998e-02  6.89114478e-02
#   6.90668594e-03  9.08687860e-03  3.94201918e-03  4.32914903e-02
#  -8.09233592e-02 -1.69112528e-02 -6.07249690e-02  1.56247774e-02
#   5.38906563e-02 -4.03796988e-02 -7.76759434e-02  2.40878003e-02
#   7.91855182e-02 -5.19676653e-02 -2.56097237e-02 -1.16753098e-01
#   3.92783155e-02 -4.74986125e-02  1.32351781e-01 -2.47040766e-02
#   3.34093210e-02 -2.00739159e-01  1.99339674e-01 -5.76365943e-02
#   5.64513058e-02 -4.78257161e-02  2.78755178e-01 -3.36594926e-02
# ...

# %%
df = pd.read_csv("train.csv")
df = df.drop(columns=["id", "date"])

df = df.drop(columns=[f"temp_{5}", f"wind_{5}", f"temp_night_{5}", f"wind_night_{5}", f"temp_night_{5}", f"ssrd_ratio_{5}"])

# for i in range(5, 14):
#     df = df.drop(columns=[f"temp_{i}", f"wind_{i}", f"temp_night_{i}", f"wind_night_{i}", f"temp_night_{i}", f"ssrd_ratio_{i}"])

# for i in range(1, 14):
#     df = df.drop(columns=[f"temp_{i}", f"temp_night_{i}", f"wind_night_{i}", f"temp_night_{i}", f"ssrd_ratio_{i}"])

# ind = 12
# for i in range(1, 14):
#     df = df.drop(columns=[f"temp_night_{i}"])

print(df.shape)
# print(df.head())

df_wo_y = df.drop(columns=['demand'])

X = df_wo_y.to_numpy()
G = X.T @ X
eigvals, eigvecs = np.linalg.eigh(X.T @ X)

print(eigvals)
# print(eigvecs[4])
# Out:
# (3287, 61)
# [8.06256841e+00 1.01065403e+01 1.28361080e+01 1.34577240e+01
#  1.38956535e+01 1.86859223e+01 2.06463167e+01 2.15303810e+01
#  2.25045525e+01 2.49451700e+01 2.54240031e+01 2.78681094e+01
#  3.03166893e+01 3.30525445e+01 3.66414661e+01 3.70208505e+01
#  4.17155743e+01 4.83463563e+01 5.73352762e+01 5.92016663e+01
#  6.35703172e+01 8.50668144e+01 8.82159505e+01 1.07518605e+02
#  1.20600535e+02 1.24591647e+02 1.46876422e+02 1.48834924e+02
#  1.78155104e+02 1.98681511e+02 2.22958607e+02 2.26862421e+02
#  2.44613081e+02 3.08243851e+02 3.22351669e+02 3.46055676e+02
#  3.62847615e+02 3.91596326e+02 4.26298819e+02 4.46809388e+02
#  4.70981565e+02 5.36624295e+02 6.14271184e+02 6.87524256e+02
#  7.10501031e+02 8.75441091e+02 9.56512079e+02 1.07788459e+03
#  1.13265338e+03 1.45782161e+03 2.32901074e+03 2.85199043e+03
#  3.39769006e+03 4.70716119e+03 7.01668527e+03 1.24112636e+04
#  1.29078322e+04 2.46416525e+04 2.56162180e+05 5.90614620e+06]

# %%
df = pd.read_csv("train.csv")
df = df.drop(columns=["id", "date"])

df = df.drop(columns=[f"temp_{5}", f"wind_{5}", f"temp_night_{5}", f"wind_night_{5}", f"temp_night_{5}", f"ssrd_ratio_{5}"])

for i in range(2, 14):
    if i != 5:
        df = df.drop(columns=[f"temp_{i}", f"wind_{i}", f"temp_night_{i}", f"wind_night_{i}", f"temp_night_{i}", f"ssrd_ratio_{i}"])

sns.pairplot(df)
plt.show()

# # for i in range(1, 14):
# #     df = df.drop(columns=[f"temp_{i}", f"temp_night_{i}", f"wind_night_{i}", f"temp_night_{i}", f"ssrd_ratio_{i}"])

# # ind = 12
# # for i in range(1, 14):
# #     df = df.drop(columns=[f"temp_night_{i}"])

# print(df.shape)
# # print(df.head())

# df_wo_y = df.drop(columns=['demand'])

# X = df_wo_y.to_numpy()
# G = X.T @ X
# eigvals, eigvecs = np.linalg.eigh(X.T @ X)

# print(eigvals)
# # print(eigvecs[4])

# %%
df = pd.read_csv("train.csv")
df = df.drop(columns=["id", "date"])

# df = df.drop(columns=[f"temp_{5}", f"wind_{5}", f"temp_night_{5}", f"wind_night_{5}", f"temp_night_{5}", f"ssrd_ratio_{5}"])

for i in range(1, 14):
    df = df.drop(columns=[f"temp_{i}", f"wind_{i}", f"temp_night_{i}", f"wind_night_{i}", f"temp_night_{i}", f"ssrd_ratio_{i}"])

sns.pairplot(df)
plt.show()

# # for i in range(1, 14):
# #     df = df.drop(columns=[f"temp_{i}", f"temp_night_{i}", f"wind_night_{i}", f"temp_night_{i}", f"ssrd_ratio_{i}"])

# # ind = 12
# # for i in range(1, 14):
# #     df = df.drop(columns=[f"temp_night_{i}"])

# print(df.shape)
# # print(df.head())

# df_wo_y = df.drop(columns=['demand'])

# X = df_wo_y.to_numpy()
# G = X.T @ X
# eigvals, eigvecs = np.linalg.eigh(X.T @ X)

# print(eigvals)
# # print(eigvecs[4])

# %%
df = pd.read_csv("train.csv")
df = df.drop(columns=["id", "date"])

df = df.drop(columns=[f"temp_{5}", f"wind_{5}", f"temp_night_{5}", f"wind_night_{5}", f"temp_night_{5}", f"ssrd_ratio_{5}"])

terms = []
for col in df.columns:
    if col == "demand":
        continue
    if col.startswith(("temp", "temp_night")):
        terms.append(col)
        terms.append(f"I({col}**3)")
    else:
        terms.append(col)

model_str = "demand ~ " + " + ".join(terms)

print(model_str)
# Out:
# demand ~ temp_1 + I(temp_1**3) + temp_night_1 + I(temp_night_1**3) + wind_1 + wind_night_1 + ssrd_ratio_1 + temp_2 + I(temp_2**3) + temp_night_2 + I(temp_night_2**3) + wind_2 + wind_night_2 + ssrd_ratio_2 + temp_3 + I(temp_3**3) + temp_night_3 + I(temp_night_3**3) + wind_3 + wind_night_3 + ssrd_ratio_3 + temp_4 + I(temp_4**3) + temp_night_4 + I(temp_night_4**3) + wind_4 + wind_night_4 + ssrd_ratio_4 + temp_6 + I(temp_6**3) + temp_night_6 + I(temp_night_6**3) + wind_6 + wind_night_6 + ssrd_ratio_6 + temp_7 + I(temp_7**3) + temp_night_7 + I(temp_night_7**3) + wind_7 + wind_night_7 + ssrd_ratio_7 + temp_8 + I(temp_8**3) + temp_night_8 + I(temp_night_8**3) + wind_8 + wind_night_8 + ssrd_ratio_8 + temp_9 + I(temp_9**3) + temp_night_9 + I(temp_night_9**3) + wind_9 + wind_night_9 + ssrd_ratio_9 + temp_10 + I(temp_10**3) + temp_night_10 + I(temp_night_10**3) + wind_10 + wind_night_10 + ssrd_ratio_10 + temp_11 + I(temp_11**3) + temp_night_11 + I(temp_night_11**3) + wind_11 + wind_night_11 + s
# ...
